# %% [markdown]
# ## Loading External Data into Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

from pandas import DataFrame, Series

# %%
# read from a csv into dataframe
df = pd.read_csv('data_sources/ex1.csv', sep=',')
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
names = ['data_a','data_b','data_c','data_d','Info']
df = pd.read_csv('data_sources/ex2.csv', sep=',', names=names, index_col='Info')
df
# Out:
#        data_a  data_b  data_c  data_d
# Info
# hello       1       2       3       4
# world       5       6       7       8
# foo         9      10      11      12

# %%
# selectively skip rows[0] [2] and [3]
df = pd.read_csv('data_sources/ex4.csv', sep=',', skiprows=[0,2,3])
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# while reading from a source, replace NA and missing values with 0
df = pd.read_csv('data_sources/ex5.csv')
df.fillna(0)
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4       0
# 1       two  5   6   0.0   8   world
# 2     three  9  10  11.0  12     foo

# %%
### now reading some large data sets (10,000 rows)
df = pd.read_csv('data_sources/ex6.csv')
df # for large data, default shows first 5 (head) and last 5 (tail)
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
df.describe()
# Out:
#                 one           two         three          four
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.045750      0.000871     -0.026463      0.015985
# std        0.948825      1.003829      1.037273      0.982409
# min       -3.726864     -3.465356     -3.234391     -3.173509
# 25%       -0.618617     -0.706643     -0.727791     -0.676291
# 50%        0.041638      0.018972     -0.032340     -0.005338
# 75%        0.701536      0.708405      0.626904      0.659369
# max        2.833891      2.946737      3.053345      3.412734

# %%
df = pd.read_csv('data_sources/ex6.csv', nrows=40) # reads top 40 rows
df
# Out:
#          one       two     three      four key
# 0   0.467976 -0.038649 -0.295344 -1.824726   L
# 1  -0.358893  1.404453  0.704965 -0.200638   B
# 2  -0.501840  0.659254 -0.421691 -0.057688   G
# 3   0.204886  1.074134  1.388361 -0.982404   R
# 4   0.354628 -0.133116  0.283763 -0.837063   Q
# 5   1.817480  0.742273  0.419395 -2.251035   Q
# 6  -0.776764  0.935518 -0.332872 -1.875641   U
# 7  -0.913135  1.530624 -0.572657  0.477252   K
# 8   0.358480 -0.497572 -0.367016  0.507702   S
# 9  -1.740877 -1.160417 -1.637830  2.172201   G
# 10  0.240564 -0.328249  1.252155  1.072796   8
# 11  0.764018  1.165476 -0.639544  1.495258   R
# 12  0.571035 -0.310537  0.582437 -0.298765   1
# 13  2.317658  0.430710 -1.334216  0.199679   P
# 14  1.547771 -1.119753 -2.277634  0.329586   J
# 15 -1.310608  0.401719 -1.000987  1.156708   E
# 16 -0.088496  0.634712  0.153324  0.415335   B
# 17 -0.018663 -0.247487 -1.446522  0.750938   A
# 18 -0.070127 -1.579097  0.120892  0.671432   F
# 19 -0.194678 -0.492039  2.359605  0.319810   H
# 20 -0.248618  0.868707 -0.492226 -0.717959   W
# 21 -1.091549 -0.867110 -0.647760 -0.832562   C
# 22  0.641404 -0.138822 -0.621963 -0.284839   C
# 23  1.216408  0.992687  0.165162 -0.069619   V
# 24 -0.564474  0.792832  0.747053  0.571675   I
# 25  1.759879 -0.515666 -0.230481  1.362317   S
# 26  0.126266  0.309281  0.382820 -0.239199   L
# 27  1.334360 -0.100152 -0.840731 -0.643967   6
# 28 -0.737620  0.278087 -0.053235 -0.950972   J
# 29 -1.148486 -0.986292 -0.144963  0.124362   Y
# 30  1.630594  0.243886  0.468368  1.258048   F
# 31  1.044890  0.080718  0.857886 -0.298382   J
# 32 -0.262543 -1.615199 -1.087239  0.759029   T
# 33  0.020144  1.107792 -0.559435 -0.481925   M
# 34 -1.203916  1.885343 -0.080470  0.250646   J
# 35  0.366915 -2.430086 -1.053447  0.346279   A
# 36  0.434220 -0.079863 -0.422977 -0.074272   I
# 37  0.040666 -1.810216 -0.189193  1.229266   G
# 38  1.338459  0.338489 -0.213446  2.325923   Q
# 39  0.572981  0.782664  1.307673  1.619957   X

# %%
chunks = pd.read_csv('data_sources/ex6.csv', chunksize=100) # reads data in chunks
alldata = pd.Series([], dtype='float64') # start off with an empty series
for piece in chunks:
    alldata = alldata.add(piece['key'].value_counts(), fill_value=0) # counts instances of values in column key
alldata
# Out:
# 0    151.0
# 1    146.0
# 2    152.0
# 3    162.0
# 4    171.0
# 5    157.0
# 6    166.0
# 7    164.0
# 8    162.0
# 9    150.0
# A    320.0
# B    302.0
# C    286.0
# D    320.0
# E    368.0
# F    335.0
# G    308.0
# H    330.0
# I    327.0
# J    337.0
# K    334.0
# L    346.0
# M    338.0
# N    306.0
# O    343.0
# P    324.0
# Q    340.0
# R    318.0
# S    308.0
# T    304.0
# U    326.0
# V    328.0
# W    305.0
# X    364.0
# Y    314.0
# Z    288.0
# dtype: float64

# %% [markdown]
# ## Reading excel and writing data out again

# %%
x_data = pd.read_excel('data_sources/ex1.xlsx')
x_data # notice the excel-index column Unnamed:0
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
x_data.to_csv('data_sources/out.csv', sep='-')

# %%
import json

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38, "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""
#type(obj) # str
r = json.loads(obj)
#type(r) # dictionary
s = pd.Series(r)
s.to_json('data_sources/wes.json')

# %% [markdown]
# ### We can use API endpoints

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
res = requests.get(url)
data = res.json() # structure of a list of dictionaries
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44041',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44041/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44041/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44041/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/44041',
#   'id': 1027024981,
#   'node_id': 'PR_kwDOAA0YD84tO2Ht',
#   'number': 44041,
#   'title': 'Fixed metadata propagation in Dataframe.apply (issue #28283)',
#   'user': {'login': 'moha-rk',
#    'id': 56267277,
#    'node_id': 'MDQ6VXNlcjU2MjY3Mjc3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56267277?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/moha-rk',
#    'html_url': 'https://github.com/moha-rk',
#    'followers_url': 'https://api.github.com/users/moha-rk/followers',
#    'following_url': 'https://api.github.com/users/moha-rk/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/moha-rk/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/moha-rk/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/moha-rk/subscriptions',
#    'organizations_url': 'https://api.github.com/users/moha-rk/orgs',
#    'repos_url': 'https://api.github.com/users/moha-rk/repos',
#    'events_url': 'https://api.github.com/users/moha-rk/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/moha-rk/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-10-15T02:53:36Z',
#   'updated_at': '2021-10-15T02:56:19Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/44041',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/44041',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/44041.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/44041.patch'},
#   'body': 'Co-authored-by: Mohamad Rkein <mohamad_rkein@usp.br>\r\nCo-authored-by: Rafael Rodrigues <rrvsrafael@gmail.com>\r\n\r\nIn reference to #28283\r\n\r\n- [ ] closes #xxxx\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [x] whatsnew entry\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44041/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44041/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44039',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44039/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44039/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44039/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/44039',
#   'id': 1026998395,
#   'node_id': 'PR_kwDOAA0YD84tOxG4',
#   'number': 44039,
#   'title': 'REF: dispatch DTI/TDI setops to RangeIndex',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-10-15T01:55:22Z',
#   'updated_at': '2021-10-15T01:55:22Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/44039',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/44039',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/44039.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/44039.patch'},
#   'body': "- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nIncludes #44019 (but not that whatsnew)\r\n\r\nI'm optimistic we can eventually dispatch all the relevant cases and then can get rid of the special-cased _fast_union/_fast_intersect.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44039/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44039/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44038',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44038/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44038/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44038/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/44038',
#   'id': 1026964224,
#   'node_id': 'PR_kwDOAA0YD84tOqGI',
#   'number': 44038,
#   'title': 'TST: added groupby apply test for nan coerce',
#   'user': {'login': 'tyvich',
#    'id': 31109639,
#    'node_id': 'MDQ6VXNlcjMxMTA5NjM5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31109639?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tyvich',
#    'html_url': 'https://github.com/tyvich',
#    'followers_url': 'https://api.github.com/users/tyvich/followers',
#    'following_url': 'https://api.github.com/users/tyvich/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tyvich/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tyvich/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tyvich/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tyvich/orgs',
#    'repos_url': 'https://api.github.com/users/tyvich/repos',
#    'events_url': 'https://api.github.com/users/tyvich/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tyvich/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-10-15T01:04:31Z',
#   'updated_at': '2021-10-15T01:04:42Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/44038',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/44038',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/44038.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/44038.patch'},
#   'body': '- [x] closes #24903\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [x] Bug was reported in #24903 that showed empty strings being coerced into Nan when certain apply was used with groupby.  Although bug has been fixed, this test identifies the issue if it were to happen again.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44038/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44038/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44037',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44037/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44037/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44037/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/44037',
#   'id': 1026865175,
#   'node_id': 'PR_kwDOAA0YD84tOWLj',
#   'number': 44037,
#   'title': 'DOC: Document and annotate Index.reindex (#40328).',
#   'user': {'login': 'ShivnarenSrinivasan',
#    'id': 71850263,
#    'node_id': 'MDQ6VXNlcjcxODUwMjYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71850263?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ShivnarenSrinivasan',
#    'html_url': 'https://github.com/ShivnarenSrinivasan',
#    'followers_url': 'https://api.github.com/users/ShivnarenSrinivasan/followers',
#    'following_url': 'https://api.github.com/users/ShivnarenSrinivasan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ShivnarenSrinivasan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ShivnarenSrinivasan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ShivnarenSrinivasan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ShivnarenSrinivasan/orgs',
#    'repos_url': 'https://api.github.com/users/ShivnarenSrinivasan/repos',
#    'events_url': 'https://api.github.com/users/ShivnarenSrinivasan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ShivnarenSrinivasan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-10-14T22:10:42Z',
#   'updated_at': '2021-10-14T22:10:52Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/44037',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/44037',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/44037.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/44037.patch'},
#   'body': '- [ ] closes #40328 \r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44037/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44037/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44035',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44035/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44035/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44035/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/44035',
#   'id': 1026816868,
#   'node_id': 'PR_kwDOAA0YD84tOMlK',
#   'number': 44035,
#   'title': 'TST: adds test for .loc on multiindex for series GH43908',
#   'user': {'login': 'KoenSR',
#    'id': 47657222,
#    'node_id': 'MDQ6VXNlcjQ3NjU3MjIy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47657222?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KoenSR',
#    'html_url': 'https://github.com/KoenSR',
#    'followers_url': 'https://api.github.com/users/KoenSR/followers',
#    'following_url': 'https://api.github.com/users/KoenSR/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/KoenSR/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/KoenSR/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/KoenSR/subscriptions',
#    'organizations_url': 'https://api.github.com/users/KoenSR/orgs',
#    'repos_url': 'https://api.github.com/users/KoenSR/repos',
#    'events_url': 'https://api.github.com/users/KoenSR/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/KoenSR/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 71268330,
#     'node_id': 'MDU6TGFiZWw3MTI2ODMzMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/MultiIndex',
#     'name': 'MultiIndex',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/86',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86/labels',
#    'id': 6840253,
#    'node_id': 'MDk6TWlsZXN0b25lNjg0MDI1Mw==',
#    'number': 86,
#    'title': '1.4',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 81,
#    'closed_issues': 857,
#    'state': 'open',
#    'created_at': '2021-06-09T18:28:42Z',
#    'updated_at': '2021-10-15T07:32:06Z',
#    'due_on': '2021-12-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-10-14T21:01:33Z',
#   'updated_at': '2021-10-15T08:43:26Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/44035',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/44035',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/44035.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/44035.patch'},
#   'body': '- [x] closes #43908\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44035/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44035/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44034',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44034/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44034/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44034/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/44034',
#   'id': 1026793624,
#   'node_id': 'PR_kwDOAA0YD84tOH9s',
#   'number': 44034,
#   'title': 'CLN: no need for suffices anymore in test_hashtable.py',
#   'user': {'login': 'realead',
#    'id': 17513912,
#    'node_id': 'MDQ6VXNlcjE3NTEzOTEy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17513912?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/realead',
#    'html_url': 'https://github.com/realead',
#    'followers_url': 'https://api.github.com/users/realead/followers',
#    'following_url': 'https://api.github.com/users/realead/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/realead/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/realead/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/realead/subscriptions',
#    'organizations_url': 'https://api.github.com/users/realead/orgs',
#    'repos_url': 'https://api.github.com/users/realead/repos',
#    'events_url': 'https://api.github.com/users/realead/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/realead/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/86',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86/labels',
#    'id': 6840253,
#    'node_id': 'MDk6TWlsZXN0b25lNjg0MDI1Mw==',
#    'number': 86,
#    'title': '1.4',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 81,
#    'closed_issues': 857,
#    'state': 'open',
#    'created_at': '2021-06-09T18:28:42Z',
#    'updated_at': '2021-10-15T07:32:06Z',
#    'due_on': '2021-12-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-10-14T20:29:13Z',
#   'updated_at': '2021-10-14T22:53:06Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/44034',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/44034',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/44034.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/44034.patch'},
#   'body': '- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nSince we have version with fused types, there is no need to call precise version (i.e. with suffices like int64, int32 and so on) any longer.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44034/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44034/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44033',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44033/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44033/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44033/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/44033',
#   'id': 1026786005,
#   'node_id': 'PR_kwDOAA0YD84tOGZ_',
#   'number': 44033,
#   'title': 'Issue38947',
#   'user': {'login': 'SabrinaMB',
#    'id': 26471522,
#    'node_id': 'MDQ6VXNlcjI2NDcxNTIy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26471522?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SabrinaMB',
#    'html_url': 'https://github.com/SabrinaMB',
#    'followers_url': 'https://api.github.com/users/SabrinaMB/followers',
#    'following_url': 'https://api.github.com/users/SabrinaMB/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/SabrinaMB/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/SabrinaMB/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/SabrinaMB/subscriptions',
#    'organizations_url': 'https://api.github.com/users/SabrinaMB/orgs',
#    'repos_url': 'https://api.github.com/users/SabrinaMB/repos',
#    'events_url': 'https://api.github.com/users/SabrinaMB/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/SabrinaMB/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 2413328,
#     'node_id': 'MDU6TGFiZWwyNDEzMzI4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Visualization',
#     'name': 'Visualization',
#     'color': '8AE234',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-10-14T20:19:30Z',
#   'updated_at': '2021-10-14T22:57:23Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/44033',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/44033',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/44033.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/44033.patch'},
#   'body': '- [ ] closes #38947\r\n- [x] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44033/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44033/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44032',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44032/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44032/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44032/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/44032',
#   'id': 1026775219,
#   'node_id': 'PR_kwDOAA0YD84tOENn',
#   'number': 44032,
#   'title': '[PERF] fixing memory leak in aggregation.pyx',
#   'user': {'login': 'realead',
#    'id': 17513912,
#    'node_id': 'MDQ6VXNlcjE3NTEzOTEy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17513912?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/realead',
#    'html_url': 'https://github.com/realead',
#    'followers_url': 'https://api.github.com/users/realead/followers',
#    'following_url': 'https://api.github.com/users/realead/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/realead/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/realead/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/realead/subscriptions',
#    'organizations_url': 'https://api.github.com/users/realead/orgs',
#    'repos_url': 'https://api.github.com/users/realead/repos',
#    'events_url': 'https://api.github.com/users/realead/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/realead/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 1045950827,
#     'node_id': 'MDU6TGFiZWwxMDQ1OTUwODI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Window',
#     'name': 'Window',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': 'rolling, ewma, expanding'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/86',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86/labels',
#    'id': 6840253,
#    'node_id': 'MDk6TWlsZXN0b25lNjg0MDI1Mw==',
#    'number': 86,
#    'title': '1.4',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 81,
#    'closed_issues': 857,
#    'state': 'open',
#    'created_at': '2021-06-09T18:28:42Z',
#    'updated_at': '2021-10-15T07:32:06Z',
#    'due_on': '2021-12-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-10-14T20:06:26Z',
#   'updated_at': '2021-10-15T01:30:15Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/44032',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/44032',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/44032.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/44032.patch'},
#   'body': '- [x] closes #43339\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nThe old memory needs to be released, before the pointer switches to the new list.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44032/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44032/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44031',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44031/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44031/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44031/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/44031',
#   'id': 1026664551,
#   'node_id': 'I_kwDOAA0YD849Mahn',
#   'number': 44031,
#   'title': 'BUG: apply swallows exceptions, shows inconsistent behaviour',
#   'user': {'login': 'gshaikov',
#    'id': 28565097,
#    'node_id': 'MDQ6VXNlcjI4NTY1MDk3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28565097?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gshaikov',
#    'html_url': 'https://github.com/gshaikov',
#    'followers_url': 'https://api.github.com/users/gshaikov/followers',
#    'following_url': 'https://api.github.com/users/gshaikov/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gshaikov/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gshaikov/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gshaikov/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gshaikov/orgs',
#    'repos_url': 'https://api.github.com/users/gshaikov/repos',
#    'events_url': 'https://api.github.com/users/gshaikov/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gshaikov/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-10-14T17:51:07Z',
#   'updated_at': '2021-10-14T17:58:14Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### \r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the master branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\n\r\n# The problem case is 2.3\r\n\r\n# --- Dataframe with 1 row ---\r\n\r\n# 1.1 instantiate dataframe with 1 row.\r\ndf_full = pd.DataFrame([{"a": 1, "b": 2, "c": 3}], columns=["a", "b", "c"])\r\nprint(f"df_full =\\n{df_full}\\n")\r\n\r\n# 1.2 returns Series with 1 element ("Series([6], dtype: float64)"").\r\ndf_full_apply_succeeded = df_full.apply(lambda row: row.sum(), axis=1)\r\nprint(\r\n    f"df_full_apply_succeeded =\\n{df_full_apply_succeeded}\\n"\r\n    f"type = {type(df_full_apply_succeeded)}\\n"\r\n)\r\n\r\n# 1.3 raises exception correctly.\r\ntry:\r\n    df_full_apply_raises = df_full.apply(lambda row: row["not_in_df"], axis=1)\r\nexcept Exception as e:\r\n    print(f"df_full_apply_raises raises with msg: {e}\\n")\r\n\r\n\r\n# --- Dataframe with no rows ---\r\n\r\n# 2.1 instantiate "Empty DataFrame".\r\ndf_empty = pd.DataFrame([], columns=["a", "b", "c"])\r\nprint(f"df_empty =\\n{df_empty}\\n")\r\n\r\n# 2.2 returns Series with 0 elements ("Series([], dtype: float64)").\r\n# behaviour mirrors example 1.2, consistent for both dataframes.\r\ndf_empty_apply_succeeded = df_empty.apply(lambda row: row.sum(), axis=1)\r\nprint(\r\n    f"df_empty_apply_succeeded =\\n{df_empty_apply_succeeded}\\n"\r\n    f"type = {type(df_empty_apply_succeeded)}\\n"\r\n)\r\n\r\n# 2.3 swallows exception and returns "Empty DataFrame".\r\n# ----> behaviour DIFFERENT from example 1.3, not consistent!\r\ndf_empty_apply_does_not_raise = df_empty.apply(lambda row: row["not_in_df"], axis=1)\r\nprint(\r\n    f"df_empty_apply_does_not_raise =\\n{df_empty_apply_does_not_raise}\\n"\r\n    f"type = {type(df_empty_apply_does_not_raise)}\\n"\r\n)\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\n__Inconsistency in semantics__\r\n\r\nWhen calling `apply` on a `DataFrame` with >1 elements and the `func` provided to `apply` raises, the exception is propagated to the caller, which is what one would expect.\r\n\r\nWhen calling `apply` on a `DataFrame` with 0 elements and the `func` provided to `apply` raises, the exception is swallowed and `apply` returns an original empty dataframe.\r\n\r\n__Inconsistency in return types__\r\n\r\nAs the code snippet demonstrates, `apply` returns `Series` in all the cases except when it fails on an empty dataframe and swallows the exception - then it returns an empty `DataFrame`. The downstream code eventually breaks but with an error which is hard to track.\r\n\r\nThis is where exceptions are swallowed: https://github.com/pandas-dev/pandas/blob/22de58e63f9271d4ddb2bf49d008c5a9550c5cc4/pandas/core/apply.py#L779-L782\r\n\r\nBecause the code doesn\'t fail right away but returns an unexpected empty `DataFrame` identical to the original, debugging this issue has been hard and time consuming.\r\n\r\n### Expected Behavior\r\n\r\nIt is reasonable to expect that both empty and non-empty dataframes should behave in the same way when it comes to errors raised inside `func` functions provided to `apply` - namely to let them propagate to the user, as it\'s done in case of non-empty dataframes.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 73c68257545b5f8530b7044f56647bd2db92e2ba\r\npython           : 3.9.0.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 19.6.0\r\nVersion          : Darwin Kernel Version 19.6.0: Tue Aug 24 20:28:00 PDT 2021; root:xnu-6153.141.40~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npa ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44031/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44031/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44030',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44030/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44030/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44030/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/44030',
#   'id': 1026357602,
#   'node_id': 'I_kwDOAA0YD849LPli',
#   'number': 44030,
#   'title': "BUG: .fillna({}) doesn't work",
#   'user': {'login': 'q121212',
#    'id': 1872019,
#    'node_id': 'MDQ6VXNlcjE4NzIwMTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1872019?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/q121212',
#    'html_url': 'https://github.com/q121212',
#    'followers_url': 'https://api.github.com/users/q121212/followers',
#    'following_url': 'https://api.github.com/users/q121212/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/q121212/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/q121212/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/q121212/subscriptions',
#    'organizations_url': 'https://api.github.com/users/q121212/orgs',
#    'repos_url': 'https://api.github.com/users/q121212/repos',
#    'events_url': 'https://api.github.com/users/q121212/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/q121212/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-10-14T12:48:42Z',
#   'updated_at': '2021-10-15T08:58:24Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### \n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the master branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\ndf = pd.DataFrame([1,2,np.nan, pd.NA], columns=['a'])\r\n\r\n# case 1\r\ndf.fillna({})\r\n\r\n# case 2\r\ndf.fillna({np.nan: {}, pd.NA: {}})\n```\n\n\n### Issue Description\n\n.fillna() doesn't work as expected for case than `value = {}`\r\n\r\nas written in ```pandas.DataFrame.fillna```:\r\n\r\n> DataFrame.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None)\r\n> \r\n> Fill NA/NaN values using the specified method.\r\n> \r\n> Parameters\r\n> \r\n> value scalar, dict, Series, or DataFrame\r\n> \r\n> Value to use to fill holes (e.g. 0), alternately a dict/Series/DataFrame of values specifying which value to use for each index (for a Series) or column (for a DataFrame). Values not in the dict/Series/DataFrame will not be filled. This value cannot be a list.\r\n> \r\n\n\n### Expected Behavior\n\nall values (`np.nan` and `pd.NA`) should be changed to `{}`\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 73c68257545b5f8530b7044f56647bd2db92e2ba\r\npython           : 3.9.6.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.10.47-linuxkit\r\nVersion          : #1 SMP Sat Jul 3 21:51:47 UTC 2021\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : en_US.UTF-8\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.3.3\r\nnumpy            : 1.20.3\r\npytz             : 2021.1\r\ndateutil         : 2.8.2\r\npip              : 21.2.4\r\nsetuptools       : 58.0.4\r\nCython           : 0.29.24\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.0.1\r\nIPython          : 7.27.0\r\npandas_datareader: None\r\nbs4              : 4.10.0\r\nbottleneck       : 1.3.2\r\nfsspec           : 2021.08.1\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.4.3\r\nnumexpr          : 2.7.3\r\nodfpy            : None\r\nopenpyxl         : 3.0.9\r\npandas_gbq       : None\r\npyarrow          : 5.0.0\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.7.1\r\nsqlalchemy       : 1.4.23\r\ntables           : 3.6.1\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : 1.2.0\r\nxlwt             : None\r\nnumba            : 0.54.0\r\n</details>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44030/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44030/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44029',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44029/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44029/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44029/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/44029',
#   'id': 1026256021,
#   'node_id': 'PR_kwDOAA0YD84tMbFh',
#   'number': 44029,
#   'title': 'ENH/CI: Add Cache for Azure pipelines ',
#   'user': {'login': 'trallard',
#    'id': 23552331,
#    'node_id': 'MDQ6VXNlcjIzNTUyMzMx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23552331?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/trallard',
#    'html_url': 'https://github.com/trallard',
#    'followers_url': 'https://api.github.com/users/trallard/followers',
#    'following_url': 'https://api.github.com/users/trallard/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/trallard/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/trallard/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/trallard/subscriptions',
#    'organizations_url': 'https://api.github.com/users/trallard/orgs',
#    'repos_url': 'https://api.github.com/users/trallard/repos',
#    'events_url': 'https://api.github.com/users/trallard/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/trallard/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-10-14T10:59:00Z',
#   'updated_at': '2021-10-14T11:56:16Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/44029',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/44029',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/44029.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/44029.patch'},
#   'body': '- [x] closes ##42580\r\n- [ ] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n\r\n\r\nTrying to leverage the use of cache on Azure pipelines - currently WIP will make some investigations ',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44029/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44029/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44027',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44027/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44027/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44027/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/44027',
#   'id': 1026132592,
#   'node_id': 'I_kwDOAA0YD849KYpw',
#   'number': 44027,
#   'title': 'Consider cibuildwheel for building wheels?',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-10-14T08:49:15Z',
#   'updated_at': '2021-10-14T08:49:15Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
# ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44007',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44007/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44007/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44007/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/44007',
#   'id': 1024759168,
#   'node_id': 'PR_kwDOAA0YD84tHvo9',
#   'number': 44007,
#   'title': 'DOC: Added DataFrame in Parameters & Return description in the docstring',
#   'user': {'login': 'abatomunkuev',
#    'id': 55283735,
#    'node_id': 'MDQ6VXNlcjU1MjgzNzM1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55283735?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abatomunkuev',
#    'html_url': 'https://github.com/abatomunkuev',
#    'followers_url': 'https://api.github.com/users/abatomunkuev/followers',
#    'following_url': 'https://api.github.com/users/abatomunkuev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/abatomunkuev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/abatomunkuev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/abatomunkuev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/abatomunkuev/orgs',
#    'repos_url': 'https://api.github.com/users/abatomunkuev/repos',
#    'events_url': 'https://api.github.com/users/abatomunkuev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/abatomunkuev/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-10-13T04:18:04Z',
#   'updated_at': '2021-10-13T22:31:07Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/44007',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/44007',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/44007.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/44007.patch'},
#   'body': '- [x] closes #41676 \r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n\r\n\r\nHello! I have added the following information to the source code (docstring of to_datetime method):\r\n1. In case when DataFrame is passed as a parameter, the to_datetime method expects the following column names (minimally "year", "month", "day"). \r\n2. The method returns Series when the DataFrame is passed. \r\n\r\nI have created Docker Image & Python Environment, then tested my docstring update by using `validate_docstrings.py` script. \r\n\r\nBefore testing my update, I have run the script on master branch. The script found 2 errors on master branch:\r\n```\r\n2 Errors found:\r\n        No extended summary found\r\n        flake8 error: E999 SyntaxError: invalid syntax\r\n```\r\n\r\nThen, I switched to my [feature branch](https://github.com/abatomunkuev/pandas/tree/issue%2341676) and run the `validate_docstrings.py` script.\r\n\r\nOutput of the script\r\n```\r\n################################################################################\r\n######################## Docstring (pandas.to_datetime) ########################\r\n################################################################################\r\n\r\nConvert argument to datetime.\r\n\r\nParameters\r\n----------\r\narg : int, float, str, datetime, list, tuple, 1-d array, Series, DataFrame/dict-like\r\n    The object to convert to a datetime. If the DataFrame is provided, the method expects \r\n    minimally the following columns ( "year", "month", "day") in the DataFrame.\r\nerrors : {\'ignore\', \'raise\', \'coerce\'}, default \'raise\'\r\n    - If \'raise\', then invalid parsing will raise an exception.\r\n    - If \'coerce\', then invalid parsing will be set as NaT.\r\n    - If \'ignore\', then invalid parsing will return the input.\r\ndayfirst : bool, default False\r\n    Specify a date parse order if `arg` is str or its list-likes.\r\n    If True, parses dates with the day first, eg 10/11/12 is parsed as\r\n    2012-11-10.\r\n\r\n    .. warning::\r\n\r\n        dayfirst=True is not strict, but will prefer to parse\r\n        with day first. If a delimited date string cannot be parsed in\r\n        accordance with the given `dayfirst` option, e.g.\r\n        ``to_datetime([\'31-12-2021\'])``, then a warning will be shown.\r\n\r\nyearfirst : bool, default False\r\n    Specify a date parse order if `arg` is str or its list-likes.\r\n\r\n    - If True parses dates with the year first, eg 10/11/12 is parsed as\r\n      2010-11-12.\r\n    - If both dayfirst and yearfirst are True, yearfirst is preceded (same\r\n      as dateutil).\r\n\r\n    .. warning::\r\n\r\n        yearfirst=True is not strict, but will prefer to parse\r\n        with year first.\r\n\r\nutc : bool, default None\r\n    Return UTC DatetimeIndex if True (converting any tz-aware\r\n    datetime.datetime objects as well).\r\nformat : str, default None\r\n    The strftime to parse time, eg "%d/%m/%Y", note that "%f" will parse\r\n    all the way up to nanoseconds.\r\n    See strftime documentation for more information on choices:\r\n    https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior.\r\nexact : bool, True by default\r\n    Behaves as:\r\n    - If True, require an exact format match.\r\n    - If False, allow the format to match anywhere in the target string.\r\n\r\nunit : str, default \'ns\'\r\n    The unit of the arg (D,s,ms,us,ns) denote the unit, which is an\r\n    integer or float number. This will be based off the origin.\r\n    Example, with unit=\'ms\' and origin=\'unix\' (the default), this\r\n    would calculate the number of milliseconds to the unix epoch start.\r\ninfer_datetime_format : bool, default False\r\n    If True and no `format` is given, attempt to infer the format of the\r\n    datetime st ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44007/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44007/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44006',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44006/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44006/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44006/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/44006',
#   'id': 1024747604,
#   'node_id': 'PR_kwDOAA0YD84tHtQJ',
#   'number': 44006,
#   'title': 'CLN: pragma no cover, post-array_ufunc',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-10-13T04:01:56Z',
#   'updated_at': '2021-10-13T04:01:56Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/44006',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/44006',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/44006.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/44006.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44006/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44006/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44005',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44005/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44005/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44005/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/44005',
#   'id': 1024658498,
#   'node_id': 'PR_kwDOAA0YD84tHdJ-',
#   'number': 44005,
#   'title': 'TST: Adding test to test_numeric, #37348',
#   'user': {'login': 'gabrieldi95',
#    'id': 29053090,
#    'node_id': 'MDQ6VXNlcjI5MDUzMDkw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29053090?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gabrieldi95',
#    'html_url': 'https://github.com/gabrieldi95',
#    'followers_url': 'https://api.github.com/users/gabrieldi95/followers',
#    'following_url': 'https://api.github.com/users/gabrieldi95/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gabrieldi95/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gabrieldi95/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gabrieldi95/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gabrieldi95/orgs',
#    'repos_url': 'https://api.github.com/users/gabrieldi95/repos',
#    'events_url': 'https://api.github.com/users/gabrieldi95/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gabrieldi95/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtype%20Conversions',
#     'name': 'Dtype Conversions',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-10-13T01:12:19Z',
#   'updated_at': '2021-10-13T14:23:09Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/44005',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/44005',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/44005.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/44005.patch'},
#   'body': "- [x] closes #37348\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n\r\nThis makes sure that comparing int to empty strings doesn't return an error.\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44005/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44005/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44003',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44003/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44003/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44003/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/44003',
#   'id': 1024514647,
#   'node_id': 'PR_kwDOAA0YD84tG-rq',
#   'number': 44003,
#   'title': '[BUG] Fix DataFrameGroupBy.boxplot with subplots=False fails for object columns',
#   'user': {'login': 'brendandrury',
#    'id': 72849852,
#    'node_id': 'MDQ6VXNlcjcyODQ5ODUy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72849852?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/brendandrury',
#    'html_url': 'https://github.com/brendandrury',
#    'followers_url': 'https://api.github.com/users/brendandrury/followers',
#    'following_url': 'https://api.github.com/users/brendandrury/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/brendandrury/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/brendandrury/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/brendandrury/subscriptions',
#    'organizations_url': 'https://api.github.com/users/brendandrury/orgs',
#    'repos_url': 'https://api.github.com/users/brendandrury/repos',
#    'events_url': 'https://api.github.com/users/brendandrury/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/brendandrury/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-10-12T22:25:43Z',
#   'updated_at': '2021-10-13T18:37:29Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/44003',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/44003',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/44003.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/44003.patch'},
#   'body': '- [x] closes #43480\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [x] whatsnew entry\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44003/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44003/timeline',
#   'performed_via_github_app': None}]

# %%
issues = pd.DataFrame(data, columns=['number','title','state','comments'])
issues
# Out:
#     number                                              title state  comments
# 0    44041  Fixed metadata propagation in Dataframe.apply ...  open         0
# 1    44039         REF: dispatch DTI/TDI setops to RangeIndex  open         0
# 2    44038       TST: added groupby apply test for nan coerce  open         0
# 3    44037  DOC: Document and annotate Index.reindex (#403...  open         0
# 4    44035  TST: adds test for .loc on multiindex for seri...  open         0
# 5    44034  CLN: no need for suffices anymore in test_hash...  open         0
# 6    44033                                         Issue38947  open         2
# 7    44032       [PERF] fixing memory leak in aggregation.pyx  open         0
# 8    44031  BUG: apply swallows exceptions, shows inconsis...  open         0
# 9    44030                      BUG: .fillna({}) doesn't work  open         2
# 10   44029             ENH/CI: Add Cache for Azure pipelines   open         0
# 11   44027         Consider cibuildwheel for building wheels?  open         0
# 12   44026  BUG: Using pd.to_datetime function in groupby....  open         2
# 13   44025  BUG: DatetimeIndex.intersection with non-ancho...  open         1
# 14   44023                 Bug multiple css selectors GH44011  open         0
# 15   44022  ENH: Ability to coerce floats when reading csv...  open         0
# 16   44021  BUG: pandas.read_fwf doesn't correctly works w...  open         0
# 17   44020                             DOC: DatetimeArray.std  open         1
# 18   44019                              BUG: RangeIndex.union  open         0
# 19   44018                    DOC: Upload cheatsheets to site  open         0
# 20   44017                                               ENH:  open         2
# 21   44015             TST: More type checking during .(i)loc  open         0
# 22   44014  BUG: Compare returns wrong results for nullabl...  open         6
# 23   44011  BUG: Multiple CSS selectors using set_table_st...  open         2
# 24   44009  BUG: Inconsistency between behavior of cumsum ...  open         1
# 25   44008  BUG: sum() and mean() return wrong values when...  open         3
# 26   44007  DOC: Added DataFrame in Parameters & Return de...  open         1
# 27   44006             CLN: pragma no cover, post-array_ufunc  open         0
# 28   44005           TST: Adding test to test_numeric, #37348  open         0
# 29   44003  [BUG] Fix DataFrameGroupBy.boxplot with subplo...  open         0
